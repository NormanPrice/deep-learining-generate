# %%
import os
import numpy as np
import tensorflow as tf

class DataProvider:
    def __init__(self, data_dir, batch_size, sequence_length):
        self.batch_size = batch_size
        self.sequence_length = sequence_length
        self.pointer = 0

        # Read the data
        file_path = os.path.join(data_dir, "10-million-password-list-top-100000.txt")
        with open(file_path, "r", encoding="utf-8") as file:
            data = file.read()

        # Create a character dictionary
        self.chars = sorted(set(data))
        self.vocabulary_size = len(self.chars)
        self.char_to_idx = {ch: idx for idx, ch in enumerate(self.chars)}
        self.idx_to_char = {idx: ch for idx, ch in enumerate(self.chars)}

        # Encode data
        self.tensor = np.array([self.char_to_idx[ch] for ch in data], dtype=np.int32)

        # Calculate number of batches
        self.num_batches = int(self.tensor.size / (self.batch_size * self.sequence_length))
        if self.num_batches == 0:
            raise ValueError("Not enough data. Make the batch size and sequence length smaller.")

        # When the data (tensor) is divided into batches, you get the input tensor
        self.tensor = self.tensor[:self.num_batches * self.batch_size * self.sequence_length]
        # Create a shifted version of the tensor for the targets
        self.target_tensor = np.roll(self.tensor, -1)

        # Split input and target tensor into batches
        self.input_batches = np.reshape(self.tensor, [self.batch_size, -1])
        self.target_batches = np.reshape(self.target_tensor, [self.batch_size, -1])

        print("Tensor size:", self.tensor.size)
        print("Batch size:", self.batch_size)
        print("Sequence length:", self.sequence_length)
        print("Number of batches:", self.num_batches)
        print("")

    def next_batch(self):
        start = self.pointer * self.sequence_length
        end = start + self.sequence_length
        inputs = self.input_batches[:, start:end]
        targets = self.target_batches[:, start:end]
        self.pointer += 1
        if self.pointer >= self.num_batches:
            self.pointer = 0
        return inputs, targets

    def reset_batch_pointer(self):
        self.pointer = 0

class RNNModel(tf.keras.Model):
    def __init__(self, vocabulary_size, sequence_length, hidden_layer_size, cells_size, gradient_clip=5.):
        super(RNNModel, self).__init__()

        self.sequence_length = sequence_length
        self.batch_size = tf.Variable(0, dtype=tf.int32, trainable=False)

        # We stack multiple LSTM layers (if cells_size > 1)
        lstm_cells = [tf.keras.layers.LSTMCell(hidden_layer_size) for _ in range(cells_size)]
        self.rnn_layer = tf.keras.layers.StackedRNNCells(lstm_cells)
        self.rnn_layer = tf.keras.layers.RNN(self.rnn_layer, return_sequences=True, return_state=True)

        self.embedding_layer = tf.keras.layers.Embedding(vocabulary_size, hidden_layer_size)
        self.softmax_layer = tf.keras.layers.Dense(vocabulary_size)

        self.gradient_clip = gradient_clip

    def call(self, inputs, states=None, return_state=False, training=False):
        if states is None:
            states = self.rnn_layer.get_initial_state(inputs)

        inputs = self.embedding_layer(inputs)
        outputs, *state = self.rnn_layer(inputs, initial_state=states, training=training)
        logits = self.softmax_layer(outputs)

        if return_state:
            return logits, state
        else:
            return logits

    def train_step(self, data):
        x, y = data
        with tf.GradientTape() as tape:
            logits = self(x, training=True)  # Forward pass
            loss = self.compiled_loss(y, logits, regularization_losses=self.losses)

        # Compute gradients
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Clip gradients and update
        clipped_gradients, _ = tf.clip_by_global_norm(gradients, self.gradient_clip)
        self.optimizer.apply_gradients(zip(clipped_gradients, trainable_vars))

        # Update the metrics configured in 'compile'.
        self.compiled_metrics.update_state(y, logits)

        # Return a dict mapping metric names to current value.
        return {m.name: m.result() for m in self.metrics}
    def sample(self, char, char_to_idx, idx_to_char, length):
        state = None
        text = ""
        for _ in range(length):
            x = np.array([[char_to_idx[char]]], dtype=np.float32)
            logits, state = self(x, states=state, return_state=True, training=False)
            probs = tf.nn.softmax(logits[-1, -1])
            idx = np.random.choice(range(len(idx_to_char)), p=probs.numpy())
            char = idx_to_char[idx]
            text += char
        return text

# Settings for the model and dataset.
batch_size = 32
sequence_length = 25
hidden_layer_size = 1024
cells_size = 3

data_provider = DataProvider("/content", batch_size, sequence_length)

# Build the model.
model = RNNModel(data_provider.vocabulary_size, sequence_length, hidden_layer_size, cells_size)

# Compile the model.
model.compile(
    optimizer='adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
)

# Train the model.
for epoch in range(75):
    data_provider.reset_batch_pointer()
    for b in range(data_provider.num_batches):
        x_batch, y_batch = data_provider.next_batch()

        # Convert batches to float32 tensors
        x_batch = tf.convert_to_tensor(x_batch, dtype=tf.float32)
        y_batch = tf.convert_to_tensor(y_batch, dtype=tf.int32)

        result = model.train_step((x_batch, y_batch))
        print(f'Epoch [{epoch}] Batch [{b}] Loss: {result["loss"]:.4f}, Accuracy: {result["accuracy"]:.4f}')

sampled_text = model.sample('h', data_provider.char_to_idx, data_provider.idx_to_char, 300)
print("Sampled text:", sampled_text)
# Out:
# Tensor size: 781600
# Batch size: 32
# Sequence length: 25
# Number of batches: 977
# WARNING:tensorflow:5 out of the last 5 calls to <function _BaseOptimizer._update_step_xla at 0x7dd33c3ee710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 6 calls to <function _BaseOptimizer._update_step_xla at 0x7dd33c3ee710> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Strumieniowane dane wyjściowe obcięte do 5000 ostatnich wierszy.
# Epoch [47] Batch [746] Loss: 0.6952, Accuracy: 0.7719
# Epoch [47] Batch [747] Loss: 0.6952, Accuracy: 0.7719
# Epoch [47] Batch [748] Loss: 0.6952, Accuracy: 0.7719
# Epoch [47] Batch [749] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [750] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [751] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [752] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [753] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [754] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [755] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [756] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [757] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [758] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [759] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [760] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [761] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [762] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [763] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [764] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [765] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [766] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [767] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [768] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [769] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [770] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [771] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [772] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [773] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [774] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [775] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [776] Loss: 0.6951, Accuracy: 0.7719
# Epoch [47] Batch [777] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [778] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [779] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [780] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [781] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [782] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [783] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [784] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [785] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [786] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [787] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [788] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [789] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [790] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [791] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [792] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [793] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [794] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [795] Loss: 0.6950, Accuracy: 0.7719
# Epoch [47] Batch [796] Loss: 0.6950, Accuracy: 0.7720
# Epoch [47] Batch [797] Loss: 0.6950, Accuracy: 0.7720
# Epoch [47] Batch [798] Loss: 0.6950, Accuracy: 0.7720
# Epoch [47] Batch [799] Loss: 0.6950, Accuracy: 0.7720
# Epoch [47] Batch [800] Loss: 0.6950, Accuracy: 0.7720
# Epoch [47] Batch [801] Loss: 0.6950, Accuracy: 0.7720
# Epoch [47] Batch [802] Loss: 0.6950, Accuracy: 0.7720
# Epoch [47] Batch [803] Loss: 0.6950, Accuracy: 0.7720
# Epoch [47] Batch [804] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [805] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [806] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [807] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [808] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [809] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [810] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [811] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [812] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [813] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [814] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [815] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [816] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [817] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [818] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [819] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [820] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [821] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [822] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [823] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [824] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [825] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [826] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [827] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [828] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [829] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [830] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [831] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [832] Loss: 0.6949, Accuracy: 0.7720
# Epoch [47] Batch [833] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [834] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [835] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [836] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [837] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [838] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [839] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [840] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [841] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [842] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [843] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [844] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [845] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [846] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [847] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [848] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [849] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [850] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [851] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [852] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [853] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [854] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [855] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [856] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [857] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [858] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [859] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [860] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [861] Loss: 0.6948, Accuracy: 0.7720
# Epoch [47] Batch [862] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [863] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [864] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [865] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [866] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [867] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [868] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [869] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [870] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [871] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [872] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [873] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [874] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [875] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [876] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [877] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [878] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [879] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [880] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [881] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [882] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [883] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [884] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [885] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [886] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [887] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [888] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [889] Loss: 0.6947, Accuracy: 0.7720
# Epoch [47] Batch [890] Loss: 0.6946, Accuracy: 0.7720
# Epoch [47] Batch [891] Loss: 0.6946, Accuracy: 0.7720
# Epoch [47] Batch [892] Loss: 0.6946, Accuracy: 0.7720
# Epoch [47] Batch [893] Loss: 0.6946, Accuracy: 0.7720
# Epoch [47] Batch [894] Loss: 0.6946, Accuracy: 0.7720
# Epoch [47] Batch [895] Loss: 0.6946, Accuracy: 0.7720
# Epoch [47] Batch [896] Loss: 0.6946, Accuracy: 0.7720
# Epoch [47] Batch [897] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [898] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [899] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [900] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [901] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [902] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [903] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [904] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [905] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [906] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [907] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [908] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [909] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [910] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [911] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [912] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [913] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [914] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [915] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [916] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [917] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [918] Loss: 0.6946, Accuracy: 0.7721
# Epoch [47] Batch [919] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [920] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [921] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [922] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [923] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [924] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [925] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [926] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [927] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [928] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [929] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [930] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [931] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [932] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [933] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [934] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [935] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [936] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [937] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [938] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [939] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [940] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [941] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [942] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [943] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [944] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [945] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [946] Loss: 0.6945, Accuracy: 0.7721
# Epoch [47] Batch [947] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [948] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [949] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [950] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [951] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [952] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [953] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [954] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [955] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [956] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [957] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [958] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [959] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [960] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [961] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [962] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [963] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [964] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [965] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [966] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [967] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [968] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [969] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [970] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [971] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [972] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [973] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [974] Loss: 0.6944, Accuracy: 0.7721
# Epoch [47] Batch [975] Loss: 0.6943, Accuracy: 0.7721
# Epoch [47] Batch [976] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [0] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [1] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [2] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [3] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [4] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [5] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [6] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [7] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [8] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [9] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [10] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [11] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [12] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [13] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [14] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [15] Loss: 0.6943, Accuracy: 0.7721
# Epoch [48] Batch [16] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [17] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [18] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [19] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [20] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [21] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [22] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [23] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [24] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [25] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [26] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [27] Loss: 0.6943, Accuracy: 0.7722
# Epoch [48] Batch [28] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [29] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [30] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [31] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [32] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [33] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [34] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [35] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [36] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [37] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [38] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [39] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [40] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [41] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [42] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [43] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [44] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [45] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [46] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [47] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [48] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [49] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [50] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [51] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [52] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [53] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [54] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [55] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [56] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [57] Loss: 0.6942, Accuracy: 0.7722
# Epoch [48] Batch [58] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [59] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [60] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [61] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [62] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [63] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [64] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [65] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [66] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [67] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [68] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [69] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [70] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [71] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [72] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [73] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [74] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [75] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [76] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [77] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [78] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [79] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [80] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [81] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [82] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [83] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [84] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [85] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [86] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [87] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [88] Loss: 0.6941, Accuracy: 0.7722
# Epoch [48] Batch [89] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [90] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [91] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [92] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [93] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [94] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [95] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [96] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [97] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [98] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [99] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [100] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [101] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [102] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [103] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [104] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [105] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [106] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [107] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [108] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [109] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [110] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [111] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [112] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [113] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [114] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [115] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [116] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [117] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [118] Loss: 0.6940, Accuracy: 0.7722
# Epoch [48] Batch [119] Loss: 0.6939, Accuracy: 0.7722
# Epoch [48] Batch [120] Loss: 0.6939, Accuracy: 0.7722
# Epoch [48] Batch [121] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [122] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [123] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [124] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [125] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [126] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [127] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [128] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [129] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [130] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [131] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [132] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [133] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [134] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [135] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [136] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [137] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [138] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [139] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [140] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [141] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [142] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [143] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [144] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [145] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [146] Loss: 0.6939, Accuracy: 0.7723
# Epoch [48] Batch [147] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [148] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [149] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [150] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [151] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [152] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [153] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [154] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [155] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [156] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [157] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [158] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [159] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [160] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [161] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [162] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [163] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [164] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [165] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [166] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [167] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [168] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [169] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [170] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [171] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [172] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [173] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [174] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [175] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [176] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [177] Loss: 0.6938, Accuracy: 0.7723
# Epoch [48] Batch [178] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [179] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [180] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [181] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [182] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [183] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [184] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [185] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [186] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [187] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [188] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [189] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [190] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [191] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [192] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [193] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [194] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [195] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [196] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [197] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [198] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [199] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [200] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [201] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [202] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [203] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [204] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [205] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [206] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [207] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [208] Loss: 0.6937, Accuracy: 0.7723
# Epoch [48] Batch [209] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [210] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [211] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [212] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [213] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [214] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [215] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [216] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [217] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [218] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [219] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [220] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [221] Loss: 0.6936, Accuracy: 0.7723
# Epoch [48] Batch [222] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [223] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [224] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [225] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [226] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [227] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [228] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [229] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [230] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [231] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [232] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [233] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [234] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [235] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [236] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [237] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [238] Loss: 0.6936, Accuracy: 0.7724
# Epoch [48] Batch [239] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [240] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [241] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [242] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [243] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [244] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [245] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [246] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [247] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [248] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [249] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [250] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [251] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [252] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [253] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [254] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [255] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [256] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [257] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [258] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [259] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [260] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [261] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [262] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [263] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [264] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [265] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [266] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [267] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [268] Loss: 0.6935, Accuracy: 0.7724
# Epoch [48] Batch [269] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [270] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [271] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [272] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [273] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [274] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [275] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [276] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [277] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [278] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [279] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [280] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [281] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [282] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [283] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [284] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [285] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [286] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [287] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [288] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [289] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [290] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [291] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [292] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [293] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [294] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [295] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [296] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [297] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [298] Loss: 0.6934, Accuracy: 0.7724
# Epoch [48] Batch [299] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [300] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [301] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [302] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [303] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [304] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [305] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [306] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [307] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [308] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [309] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [310] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [311] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [312] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [313] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [314] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [315] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [316] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [317] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [318] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [319] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [320] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [321] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [322] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [323] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [324] Loss: 0.6933, Accuracy: 0.7724
# Epoch [48] Batch [325] Loss: 0.6933, Accuracy: 0.7725
# Epoch [48] Batch [326] Loss: 0.6933, Accuracy: 0.7725
# Epoch [48] Batch [327] Loss: 0.6933, Accuracy: 0.7725
# Epoch [48] Batch [328] Loss: 0.6933, Accuracy: 0.7725
# Epoch [48] Batch [329] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [330] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [331] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [332] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [333] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [334] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [335] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [336] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [337] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [338] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [339] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [340] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [341] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [342] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [343] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [344] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [345] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [346] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [347] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [348] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [349] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [350] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [351] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [352] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [353] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [354] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [355] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [356] Loss: 0.6932, Accuracy: 0.7725
# Epoch [48] Batch [357] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [358] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [359] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [360] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [361] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [362] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [363] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [364] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [365] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [366] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [367] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [368] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [369] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [370] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [371] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [372] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [373] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [374] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [375] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [376] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [377] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [378] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [379] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [380] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [381] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [382] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [383] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [384] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [385] Loss: 0.6931, Accuracy: 0.7725
# Epoch [48] Batch [386] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [387] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [388] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [389] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [390] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [391] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [392] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [393] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [394] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [395] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [396] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [397] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [398] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [399] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [400] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [401] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [402] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [403] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [404] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [405] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [406] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [407] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [408] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [409] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [410] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [411] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [412] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [413] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [414] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [415] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [416] Loss: 0.6930, Accuracy: 0.7725
# Epoch [48] Batch [417] Loss: 0.6929, Accuracy: 0.7725
# Epoch [48] Batch [418] Loss: 0.6929, Accuracy: 0.7725
# Epoch [48] Batch [419] Loss: 0.6929, Accuracy: 0.7725
# Epoch [48] Batch [420] Loss: 0.6929, Accuracy: 0.7725
# Epoch [48] Batch [421] Loss: 0.6929, Accuracy: 0.7725
# Epoch [48] Batch [422] Loss: 0.6929, Accuracy: 0.7725
# Epoch [48] Batch [423] Loss: 0.6929, Accuracy: 0.7725
# Epoch [48] Batch [424] Loss: 0.6929, Accuracy: 0.7725
# Epoch [48] Batch [425] Loss: 0.6929, Accuracy: 0.7725
# Epoch [48] Batch [426] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [427] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [428] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [429] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [430] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [431] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [432] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [433] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [434] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [435] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [436] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [437] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [438] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [439] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [440] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [441] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [442] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [443] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [444] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [445] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [446] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [447] Loss: 0.6929, Accuracy: 0.7726
# Epoch [48] Batch [448] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [449] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [450] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [451] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [452] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [453] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [454] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [455] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [456] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [457] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [458] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [459] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [460] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [461] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [462] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [463] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [464] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [465] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [466] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [467] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [468] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [469] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [470] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [471] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [472] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [473] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [474] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [475] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [476] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [477] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [478] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [479] Loss: 0.6928, Accuracy: 0.7726
# Epoch [48] Batch [480] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [481] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [482] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [483] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [484] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [485] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [486] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [487] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [488] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [489] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [490] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [491] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [492] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [493] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [494] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [495] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [496] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [497] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [498] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [499] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [500] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [501] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [502] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [503] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [504] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [505] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [506] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [507] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [508] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [509] Loss: 0.6927, Accuracy: 0.7726
# Epoch [48] Batch [510] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [511] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [512] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [513] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [514] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [515] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [516] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [517] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [518] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [519] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [520] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [521] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [522] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [523] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [524] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [525] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [526] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [527] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [528] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [529] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [530] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [531] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [532] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [533] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [534] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [535] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [536] Loss: 0.6926, Accuracy: 0.7726
# Epoch [48] Batch [537] Loss: 0.6926, Accuracy: 0.7727
# Epoch [48] Batch [538] Loss: 0.6926, Accuracy: 0.7727
# Epoch [48] Batch [539] Loss: 0.6926, Accuracy: 0.7727
# Epoch [48] Batch [540] Loss: 0.6926, Accuracy: 0.7727
# Epoch [48] Batch [541] Loss: 0.6926, Accuracy: 0.7727
# Epoch [48] Batch [542] Loss: 0.6926, Accuracy: 0.7727
# Epoch [48] Batch [543] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [544] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [545] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [546] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [547] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [548] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [549] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [550] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [551] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [552] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [553] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [554] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [555] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [556] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [557] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [558] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [559] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [560] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [561] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [562] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [563] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [564] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [565] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [566] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [567] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [568] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [569] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [570] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [571] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [572] Loss: 0.6925, Accuracy: 0.7727
# Epoch [48] Batch [573] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [574] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [575] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [576] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [577] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [578] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [579] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [580] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [581] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [582] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [583] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [584] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [585] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [586] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [587] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [588] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [589] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [590] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [591] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [592] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [593] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [594] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [595] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [596] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [597] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [598] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [599] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [600] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [601] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [602] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [603] Loss: 0.6924, Accuracy: 0.7727
# Epoch [48] Batch [604] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [605] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [606] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [607] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [608] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [609] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [610] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [611] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [612] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [613] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [614] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [615] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [616] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [617] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [618] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [619] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [620] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [621] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [622] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [623] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [624] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [625] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [626] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [627] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [628] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [629] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [630] Loss: 0.6923, Accuracy: 0.7727
# Epoch [48] Batch [631] Loss: 0.6923, Accuracy: 0.7727
# ...
# Epoch [52] Batch [565] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [566] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [567] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [568] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [569] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [570] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [571] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [572] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [573] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [574] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [575] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [576] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [577] Loss: 0.6811, Accuracy: 0.7759
# Epoch [52] Batch [578] Loss: 0.6811, Accuracy: 0.7760
# Epoch [52] Batch [579] Loss: 0.6811, Accuracy: 0.7760
# Epoch [52] Batch [580] Loss: 0.6811, Accuracy: 0.7760
# Epoch [52] Batch [581] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [582] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [583] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [584] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [585] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [586] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [587] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [588] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [589] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [590] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [591] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [592] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [593] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [594] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [595] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [596] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [597] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [598] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [599] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [600] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [601] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [602] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [603] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [604] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [605] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [606] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [607] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [608] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [609] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [610] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [611] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [612] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [613] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [614] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [615] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [616] Loss: 0.6810, Accuracy: 0.7760
# Epoch [52] Batch [617] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [618] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [619] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [620] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [621] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [622] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [623] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [624] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [625] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [626] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [627] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [628] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [629] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [630] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [631] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [632] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [633] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [634] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [635] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [636] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [637] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [638] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [639] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [640] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [641] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [642] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [643] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [644] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [645] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [646] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [647] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [648] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [649] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [650] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [651] Loss: 0.6809, Accuracy: 0.7760
# Epoch [52] Batch [652] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [653] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [654] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [655] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [656] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [657] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [658] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [659] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [660] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [661] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [662] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [663] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [664] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [665] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [666] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [667] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [668] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [669] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [670] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [671] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [672] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [673] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [674] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [675] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [676] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [677] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [678] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [679] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [680] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [681] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [682] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [683] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [684] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [685] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [686] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [687] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [688] Loss: 0.6808, Accuracy: 0.7760
# Epoch [52] Batch [689] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [690] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [691] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [692] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [693] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [694] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [695] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [696] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [697] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [698] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [699] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [700] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [701] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [702] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [703] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [704] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [705] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [706] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [707] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [708] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [709] Loss: 0.6807, Accuracy: 0.7760
# Epoch [52] Batch [710] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [711] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [712] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [713] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [714] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [715] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [716] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [717] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [718] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [719] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [720] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [721] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [722] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [723] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [724] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [725] Loss: 0.6807, Accuracy: 0.7761
# Epoch [52] Batch [726] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [727] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [728] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [729] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [730] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [731] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [732] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [733] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [734] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [735] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [736] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [737] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [738] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [739] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [740] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [741] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [742] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [743] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [744] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [745] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [746] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [747] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [748] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [749] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [750] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [751] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [752] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [753] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [754] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [755] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [756] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [757] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [758] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [759] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [760] Loss: 0.6806, Accuracy: 0.7761
# Epoch [52] Batch [761] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [762] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [763] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [764] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [765] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [766] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [767] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [768] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [769] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [770] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [771] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [772] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [773] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [774] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [775] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [776] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [777] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [778] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [779] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [780] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [781] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [782] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [783] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [784] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [785] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [786] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [787] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [788] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [789] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [790] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [791] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [792] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [793] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [794] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [795] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [796] Loss: 0.6805, Accuracy: 0.7761
# Epoch [52] Batch [797] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [798] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [799] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [800] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [801] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [802] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [803] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [804] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [805] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [806] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [807] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [808] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [809] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [810] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [811] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [812] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [813] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [814] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [815] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [816] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [817] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [818] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [819] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [820] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [821] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [822] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [823] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [824] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [825] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [826] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [827] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [828] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [829] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [830] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [831] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [832] Loss: 0.6804, Accuracy: 0.7761
# Epoch [52] Batch [833] Loss: 0.6803, Accuracy: 0.7761
# Epoch [52] Batch [834] Loss: 0.6803, Accuracy: 0.7761
# Epoch [52] Batch [835] Loss: 0.6803, Accuracy: 0.7761
# Epoch [52] Batch [836] Loss: 0.6803, Accuracy: 0.7761
# Epoch [52] Batch [837] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [838] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [839] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [840] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [841] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [842] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [843] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [844] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [845] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [846] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [847] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [848] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [849] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [850] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [851] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [852] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [853] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [854] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [855] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [856] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [857] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [858] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [859] Loss: 0.6803, Accuracy: 0.7762
# Epoch [52] Batch [860] Loss: 0.6803, Accuracy: 0.7762
